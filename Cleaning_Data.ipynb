# %% [markdown]
# # Cleaning and Transforming Data for F1 Machine Learning Model

# %% [markdown]
# ## Imports

# %%
import fastf1
import pandas as pd
fastf1.Cache.enable_cache("cache")

# %% [markdown]
# ## References
# - https://medium.com/@nityachintan/how-i-built-an-f1-race-prediction-app-as-my-first-machine-learning-project-7e2e9cc89826
# - https://docs.fastf1.dev/

# %% [markdown]
# ## Creating schedule variable

# %%
schedule_2024 = fastf1.get_event_schedule(2024, include_testing=False)

schedule_2025 = fastf1.get_event_schedule(2025, include_testing=False)

schedule_2024 = schedule_2024[["RoundNumber", "EventDate", "EventName"]]

schedule_2025 = schedule_2025[["RoundNumber", "EventDate", "EventName"]]

events = ["Qualifying", "Race"]

# %% [markdown]
# ## Getting Data needed for possible use
# - Driver - Experience, Name, Form, Consistency
# - Team - Team points trend, DNF Rate,
# - Qualifying - Grid Position, Sector Times, Tyre used
# - Race - Average lap time, pit strategy, stint lengths
# - Context - Weather and Round Number
