# %% [markdown]
# # Cleaning and Transforming Data for F1 Machine Learning Model

# %% [markdown]
# ### Imports

# %%
import fastf1
import pandas as pd
fastf1.Cache.enable_cache("cache")
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ### References
# - https://medium.com/@nityachintan/how-i-built-an-f1-race-prediction-app-as-my-first-machine-learning-project-7e2e9cc89826
# - https://docs.fastf1.dev/
# - https://arno.uvt.nl/show.cgi?fid=180319

# %% [markdown]
# ## Cleaning Race Data

# %%
race_2024_laps = pd.read_csv("Raw_Data/2024_Race_Laps.csv")
race_2024_results = pd.read_csv("Raw_Data/2024_Race_Results.csv")
race_2024_weather = pd.read_csv("Raw_Data/2024_Race_Weather.csv")

race_2025_laps = pd.read_csv("Raw_Data/2025_Race_Laps.csv")
race_2025_results = pd.read_csv("Raw_Data/2025_Race_Results.csv")
race_2025_weather = pd.read_csv("Raw_Data/2025_Race_Weather.csv")

# %% [markdown]
# ### Creating Year Column

# %%
race_2024_laps["Year"] = 2024

# %%
race_2025_laps["Year"] = 2025

# %% [markdown]
# ### Creating DriverId Column

# %%
# Creating a map to map the Drivers abreviation to an ID
driver_id_map = {
    'VER':'max_verstappen',
    'GAS':'gasly',
    'ANT':'antonelli',
    'ALO':'alonso',
    'LEC':"leclerc",
    'STR':'stroll',
    'TSU':'tsunoda',
    'ALB':'albon',
    'HUL':'hulkenberg',
    'LAW':'lawson', 
    'OCO':'ocon',
    'NOR':'norris', 
    'HAM':'hamilton',
    'BOR':'bortoleto', 
    'SAI':'sainz',
    'HAD':"hadjar",
    'RUS':'russell',
    'PIA':"piastri",
    'BEA':"bearman",
    'COL':"colapinto",
    'DOO':"doohan",
    "PER":"perez",
    "ZHO":"zhou",
    "MAG":"kevin_magnussen",
    "RIC":"ricciardo",
    "BOT":"bottas",
    "SAR":"sargeant"

}

# Mapping by Taking the driver column values and locating it within the driver id map
race_2024_laps["DriverID"] = race_2024_laps["Driver"].map(driver_id_map).str.strip().astype("string")

race_2025_laps["DriverID"] = race_2025_laps["Driver"].map(driver_id_map).str.strip().astype("string")

# %% [markdown]
# ### Dropping Redundant/Null Columns

# %%
cols_to_drop_laps = ["DeletedReason","IsAccurate","FastF1Generated","IsPersonalBest","LapStartDate"]

# %%
race_2024_laps.drop(columns=cols_to_drop_laps,inplace=True)

race_2025_laps.drop(columns=cols_to_drop_laps,inplace=True)

# %% [markdown]
# ### Time Data Columns

# %%
time_columns = ['Time','LapTime','PitOutTime', 'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time','Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime',"LapStartTime"]

race_2025_laps[time_columns] = race_2025_laps[time_columns].apply(pd.to_timedelta)

race_2024_laps[time_columns] = race_2024_laps[time_columns].apply(pd.to_timedelta)

# %% [markdown]
# ## Race Weather Data

# %% [markdown]
# ### Creating Year Column

# %%
race_2024_weather["Year"] = 2024

race_2025_weather["Year"] = 2025

# %% [markdown]
# ### Weather Time Columns

# %%
race_2024_weather["Time"] = pd.to_timedelta(race_2024_weather["Time"])

race_2025_weather["Time"] = pd.to_timedelta(race_2025_weather["Time"])

# %% [markdown]
# ### Merging Race Weather Data with Race Lap Data

# %%
# Creating empty list to append data too
merged_data_2024 = []

# Looping through each roundnumber in the 2024 dataset and sorting values to ensure it loops in the correct order
for round_2024 in sorted(race_2024_laps["RoundNumber"].unique()):

    # Creating a variables for the lap data and sorting values for later merge
    laps_2024 = (
        race_2024_laps[race_2024_laps["RoundNumber"] == round_2024].sort_values("Time")
    )

    # Creating weather data variable where the round number is equal to the part of the loop
    weather_2024 = (
        race_2024_weather[race_2024_weather["RoundNumber"] == round_2024].sort_values("Time")
    )

    # Merging the two variables on time using direction backword to ensure it takes the weather data less than or eqaul to that time period
    merge_2024 = pd.merge_asof(
        laps_2024, weather_2024, on="Time", direction="backward"
    )

    # Finally appending the data to the original empty list
    merged_data_2024.append(merge_2024)

# Concatinating the data into one dataset 
race_2024_data = pd.concat(merged_data_2024, ignore_index=True)

# %%
# Dropping and renaming columns that were created during the merge
cols_drop = ['RoundNumber_y', 'Year_y']

cols_rename = {'RoundNumber_x':'RoundNumber', 'Year_x':'Year'}

race_2024_data.drop(columns=cols_drop,inplace=True)

race_2024_data.rename(columns=cols_rename,inplace=True)

# %%
# Same process as above but for 2025 data
merged_data_2025 = []

for round_2025 in sorted(race_2025_laps["RoundNumber"].unique()):
    laps_2025 = (
        race_2025_laps[race_2025_laps["RoundNumber"] == round_2025].sort_values("Time")
    )

    weather_2025 = (
        race_2025_weather[race_2025_weather["RoundNumber"] == round_2025].sort_values("Time")
    )

    merge_2025 = pd.merge_asof(
        laps_2025, weather_2025, on="Time", direction="backward"
    )

    merged_data_2025.append(merge_2025)


race_2025_data = pd.concat(merged_data_2025, ignore_index=True)

# %%
cols_drop = ['RoundNumber_y', 'Year_y']

cols_rename = {'RoundNumber_x':'RoundNumber', 'Year_x':'Year'}

race_2025_data.drop(columns=cols_drop,inplace=True)

race_2025_data.rename(columns=cols_rename,inplace=True)

# %% [markdown]
# ### Joining 2025 and 2024 Datasets

# %%
merger = [race_2024_data, race_2025_data]

race_data = pd.concat(merger, ignore_index=True)

# %% [markdown]
# ### Writing Data to CSV

# %%
race_data.to_csv("Cleaned_Data/Cleaned_Race_Data.csv",index=False)

# %% [markdown]
# ## Inspection of Cleaned Race Data

# %%
full_df = pd.read_csv("Cleaned_Data/Cleaned_Race_Data.csv")

# %%
full_df.shape
# Out:
# (48938, 36)

# %% [markdown]
# ### Null Values

# %%
print(f"Percentage of null values : {(full_df.isnull().sum() / len(full_df)) * 100}")
# Out:
# Percentage of null values : Time                   0.000000
# Driver                 0.000000
# DriverNumber           0.000000
# LapTime                1.567289
# LapNumber              0.000000
# Stint                  0.911357
# PitOutTime            96.789816
# PitInTime             96.820467
# Sector1Time            1.994360
# Sector2Time            0.165516
# Sector3Time            0.214557
# Sector1SessionTime     2.210961
# Sector2SessionTime     0.165516
# Sector3SessionTime     0.214557
# SpeedI1               15.721934
# SpeedI2                0.210470
# SpeedFL                3.340962
# SpeedST                8.077568
# Compound               1.027831
# TyreLife               1.074829
# FreshTyre              0.000000
# Team                   0.000000
# LapStartTime           0.000000
# TrackStatus            0.000000
# Position               0.116474
# Deleted                0.000000
# RoundNumber            0.000000
# Year                   0.000000
# DriverID               0.000000
# AirTemp                0.000000
# Humidity               0.000000
# Pressure               0.000000
# Rainfall               0.000000
# TrackTemp              0.000000
# WindDirection          0.000000
# WindSpeed              0.000000
# dtype: float64

# %% [markdown]
# ### Driver Column

# %%
# Driver and Driver ID match so drop Driver Column
full_df[["Driver","DriverID"]].value_counts()

full_df.drop(columns="Driver",inplace=True)

# %% [markdown]
# ### Driver Number Column

# %%
# Similar to Driver Column not needed due to Driver ID Column
full_df[["DriverID", "DriverNumber"]].value_counts()

full_df.drop(columns="DriverNumber", inplace=True)

# %% [markdown]
# ### LapTime Column

# %%
# Convert to timedlta for time series aggregation
full_df["LapTime"] = pd.to_timedelta(full_df["LapTime"])

# %%
# Convert to total seconds for easier analysis
full_df["LapTime"] = full_df["LapTime"].dt.total_seconds()

# %%
# 548 Null values will need to fill these values 
full_df["LapTime"].isnull().sum()
# Out:
# 767

# %% [markdown]
# ### LapNumber Column

# %%
# Dropping First lap data as will skew results
full_df = full_df[full_df["LapNumber"] != 1]

# %% [markdown]
# ### Stint Column

# %%
# 427 Null values here will need to fill these seems to be the first 24 laps from round number 6 in year 2025
full_df["Stint"].isnull().sum()
null_stint_values = full_df[full_df["Stint"].isnull()]

# %% [markdown]
# ### Pit In and out Time Column

# %%
# Mostly null values wont be used in final dataset
# Will use these columns to create a laptype column that specifies whether the lap is an inlap, outlap or normal lap
full_df["PitInTime"].isnull().sum()
# Out:
# 46558

# %%
full_df["PitOutTime"].isnull().sum()
# Out:
# 46545

# %% [markdown]
# ### Sector 1, 2, 3 Time Columns

# %%
sector_times = ['Sector1Time', 'Sector2Time', 'Sector3Time']

# Very small amount of null values may just drop these rows 
full_df[sector_times].isnull().sum()

full_df[sector_times] = full_df[sector_times].apply(pd.to_timedelta)

# %%
# Deleting data where the sector times are null
full_df = full_df[~full_df["Sector1Time"].isnull()]
full_df = full_df[~full_df["Sector2Time"].isnull()]
full_df = full_df[~full_df["Sector3Time"].isnull()]

# %%
# Converting to Total Seconds similar to laptimes 
full_df["Sector1Time"] = full_df["Sector1Time"].dt.total_seconds()
full_df["Sector2Time"] = full_df["Sector2Time"].dt.total_seconds()
full_df["Sector3Time"] = full_df["Sector3Time"].dt.total_seconds()

# %% [markdown]
# ### Sector 1, 2, 3 Session Times

# %%
# Not neccesary for analysis so will be dropped
ses_times = ['Sector1SessionTime',
       'Sector2SessionTime', 'Sector3SessionTime']
full_df.drop(columns=ses_times, inplace=True)

# %% [markdown]
# ### Speed Trap Columns

# %%
st = ['SpeedI1', 'SpeedI2',
       'SpeedFL', 'SpeedST']

# Some null values, dont think will use these columns but will be evaluated further for now
full_df[st].isnull().sum()
# Out:
# SpeedI1    7613
# SpeedI2      24
# SpeedFL    1495
# SpeedST    3852
# dtype: int64

# %% [markdown]
# ### Compound Column

# %%
full_df["Compound"].isnull().sum()
# 484 values are null will have to try fill these
# Out:
# 484

# %% [markdown]
# ### TyreLife Column

# %%
full_df[full_df["TyreLife"].isnull()]
# 507 null values will need to fill these
# Out:
#                          Time  LapTime  LapNumber  Stint  \
# 27281  0 days 02:24:57.034000  113.822       40.0    5.0
# 27297  0 days 02:26:26.183000   89.149       41.0    5.0
# 27313  0 days 02:27:53.786000   87.603       42.0    5.0
# 27329  0 days 02:29:24.843000   91.057       43.0    5.0
# 27351  0 days 02:31:27.804000  122.961       44.0    5.0
# ...                       ...      ...        ...    ...
# 40696  0 days 03:41:08.526000  106.061       44.0    3.0
# 40700  0 days 03:41:21.679000  106.911       44.0    3.0
# 40701  0 days 03:41:22.877000  107.306       44.0    3.0
# 40702  0 days 03:41:26.977000  106.423       44.0    3.0
# 40703  0 days 03:41:30.238000  106.488       44.0    3.0
#
#                    PitOutTime               PitInTime  Sector1Time  \
# 27281  0 days 02:23:05.453000                     NaN       47.593
# 27297                     NaN                     NaN       31.306
# 27313                     NaN                     NaN       30.422
# 27329                     NaN                     NaN       30.290
# 27351                     NaN  0 days 02:31:10.506000       30.419
# ...                       ...                     ...          ...
# 40696                     NaN                     NaN       30.499
# 40700                     NaN                     NaN       30.734
# 40701                     NaN                     NaN       31.011
# 40702                     NaN                     NaN       31.206
# 40703                     NaN                     NaN       30.838
#
#        Sector2Time  Sector3Time  SpeedI1  ...  RoundNumber  Year    DriverID  \
# 27281       25.942       40.287    146.0  ...            1  2025     bearman
# 27297       19.948       37.895    252.0  ...            1  2025     bearman
# 27313       19.362       37.819    257.0  ...            1  2025     bearman
# 27329       19.299       41.468    263.0  ...            1  2025     bearman
# 27351       19.282       73.260    268.0  ...            1  2025     bearman
# ...            ...          ...      ...  ...          ...   ...         ...
# 40696       46.821       28.741    333.0  ...           13  2025  hulkenberg
# 40700       47.506       28.671    340.0  ...           13  2025   antonelli
# 40701       46.969       29.326    333.0  ...           13  2025      alonso
# 40702       46.291       28.926    319.0  ...           13  2025       sainz
# 40703       47.107       28.543    325.0  ...           13  2025   colapinto
#
#       AirTemp  Humidity  Pressure Rainfall TrackTemp  WindDirection  WindSpeed
# 27281    16.4      69.0    1010.3    False      19.3            255        3.6
# 27297    16.5      69.0    1010.4    False      19.3            262        3.9
# 27313    16.6      68.0    1010.6    False      19.3            222        5.1
# 27329    16.6      75.0    1010.5    False      19.3            201        1.3
# 27351    16.1      77.0    1010.3     True      19.3              0        3.5
# ...       ...       ...       ...      ...       ...            ...        ...
# 40696    16.9      83.0     965.2    False      22.4            220        1.1
# 40700    16.9      83.0     965.2    False      22.4            220        1.1
# 40701    16.9      83.0     965.2    False      22.4            220        1.1
# 40702    16.9      83.0     965.2    False      22.4            220        1.1
# 40703    16.9      83.0     965.2    False      22.4            220        1.1
#
# [507 rows x 31 columns]

# %% [markdown]
# ### FreshTyre

# %%
# No Null values not sure whether this will be useful for analysis but will be taken for now
full_df["FreshTyre"].value_counts()
# Out:
# FreshTyre
# True     37869
# False    10081
# Name: count, dtype: int64

# %% [markdown]
# ### Team Column

# %%
# No Null values and data is correct may create a power ranking type column evaluating team performance on that round number
full_df[["DriverID","Team"]].value_counts()
# Out:
# DriverID         Team
# norris           McLaren            2585
# russell          Mercedes           2563
# piastri          McLaren            2554
# leclerc          Ferrari            2554
# max_verstappen   Red Bull Racing    2481
# alonso           Aston Martin       2353
# stroll           Aston Martin       2351
# gasly            Alpine             2296
# albon            Williams           2183
# bottas           Kick Sauber        1333
# hamilton         Mercedes           1320
# zhou             Kick Sauber        1318
# sainz            Ferrari            1316
# hulkenberg       Haas F1 Team       1276
# bearman          Haas F1 Team       1249
# perez            Red Bull Racing    1239
# tsunoda          RB                 1223
# ocon             Alpine             1213
# kevin_magnussen  Haas F1 Team       1211
# ocon             Haas F1 Team       1146
# hamilton         Ferrari            1137
# bortoleto        Kick Sauber        1092
# hadjar           Racing Bulls       1090
# hulkenberg       Kick Sauber        1082
# antonelli        Mercedes           1054
# tsunoda          Red Bull Racing    1020
# sainz            Williams            991
# ricciardo        RB                  978
# lawson           Racing Bulls        920
# colapinto        Alpine              803
# sargeant         Williams            754
# colapinto        Williams            389
# lawson           RB                  350
# doohan           Alpine              267
# tsunoda          Racing Bulls        110
# lawson           Red Bull Racing     100
# bearman          Ferrari              49
# Name: count, dtype: int64

# %%
full_df = full_df.replace(to_replace="RB",value="Racing Bulls")

# %% [markdown]
# ### LapStartTime Column

# %%
# No null values, unsure whether this will be useful or not so will be kept for now 
full_df["LapStartTime"].head()
# Out:
# 20    0 days 01:01:37.489000
# 21    0 days 01:01:38.476000
# 22    0 days 01:01:39.433000
# 23    0 days 01:01:40.258000
# 24    0 days 01:01:40.825000
# Name: LapStartTime, dtype: object

# %% [markdown]
# ### TrackStatus

# %%
# No Null Values, will be important as this shows if there were any yellow flags, safety car, etc.
full_df["TrackStatus"].isnull().sum()
# Out:
# 0

# %%
ts_mapping = {
    1 : "Track Clear",
    2 : "Yellow Flag",
    4 : "Safety Car",
    5 : "Red Flag",
    6 : "VSC Deployed",
    7 : "VSC Ending"
}

full_df["TrackStatus"] = full_df["TrackStatus"].map(ts_mapping).str.strip().astype("string")

# %%
# Will help in identifying any irregular lap times, will keep for now 
full_df["TrackStatus"] = full_df["TrackStatus"].fillna("Unknown")

# %% [markdown]
# ### Position Column

# %%
# No Null values and all values seem correct, will be keeping this column
full_df["Position"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Deleted Column

# %%
# No null values, with values either being true or false may help in identifying laps that may skew the data will keep for now
full_df["Deleted"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### AirTemp Column

# %%
# No Null values, will keep for now may affect lap times 
full_df["AirTemp"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Humidity Column

# %%
# No Null values, will keep for now 
full_df["Humidity"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Pressure

# %%
# No Null values, will keep for now
full_df["Pressure"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Rainfall Column

# %%
# No Null values, either true or false, will definitley affect lap times
full_df["Rainfall"].value_counts()
# Out:
# Rainfall
# False    46018
# True      1932
# Name: count, dtype: int64

# %% [markdown]
# ### TrackTemp

# %%
# May effect lap times, will keep for now, no null values
full_df["TrackTemp"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### WindDirection

# %%
# No Null values, will keep for now may effect lap times
full_df["WindDirection"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### WindSpeed Column

# %%
# No Null values, will be taken for now to see if it effects lap times 
full_df["WindSpeed"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Time Column

# %%
# Dropping as unnesecary for analysis
full_df.drop(columns="Time",inplace=True)

# %% [markdown]
# ### Final Dataset after Inspection

# %%
full_df.isnull().sum()
# Out:
# LapTime            460
# LapNumber            0
# Stint              427
# PitOutTime       46475
# PitInTime        46456
# Sector1Time          0
# Sector2Time          0
# Sector3Time          0
# SpeedI1           7613
# SpeedI2             24
# SpeedFL           1495
# SpeedST           3852
# Compound           484
# TyreLife           507
# FreshTyre            0
# Team                 0
# LapStartTime         0
# TrackStatus          0
# Position             0
# Deleted              0
# RoundNumber          0
# Year                 0
# DriverID             0
# AirTemp              0
# Humidity             0
# Pressure             0
# Rainfall             0
# TrackTemp            0
# WindDirection        0
# WindSpeed            0
# dtype: int64

# %% [markdown]
# ## Feauture Creation

# %% [markdown]
# ### Lap Type

# %%
def get_lap_type(row):
    if pd.notnull(row["PitInTime"]):
        return "InLap"
    elif pd.notnull(row["PitOutTime"]):
        return "OutLap"
    else:
        return "Lap"
    
full_df["LapType"] = full_df.apply(get_lap_type,axis=1)

full_df.drop(columns={"PitInTime", "PitOutTime"}, inplace=True)

# %% [markdown]
# ### New Round Number Column

# %%
full_df["Year"] = full_df["Year"].astype("string")

full_df["RoundNumber"] = full_df["RoundNumber"].astype("string")

def get_round_col(row):
    if row["Year"] == "2024":
        return "2024_" + row["RoundNumber"]
    else:
        return "2025_" + row["RoundNumber"]
    
full_df["RoundYear"] = full_df.apply(get_round_col,axis=1)

full_df.drop(columns={"Year", "RoundNumber"},inplace=True)

# %% [markdown]
# ### Team Power Ranking

# %%
# Creating Power Ranking by taking each teams median lap time
# Firstly grouping by round number and Team, taking the median laptime and creating a new variable with this groupby
team_ranking = full_df.groupby(["RoundYear", "Team"])["LapTime"].median().reset_index(name="MedianLapTime")

# Creating a rank by grouping by each teams round numbers median lap time and ranking
team_ranking["Rank"] = (team_ranking.groupby(["RoundYear"])["MedianLapTime"].rank(method="dense",ascending=True))

# %%
# Merge the rankingh data to main dataframe
full_df = full_df.merge(team_ranking, on=['RoundYear', 'Team'], how="left")

# %% [markdown]
# ## Data Pre Processing

# %% [markdown]
# ## Missing Values

# %% [markdown]
# ### LapTime Column

# %%
# Adding up sector times to fill the na values in laptime 
full_df["LapTime"].fillna(full_df["Sector1Time"] + full_df["Sector2Time"] + full_df["Sector3Time"], inplace=True)
# Out:
# C:\Users\Cillian\AppData\Local\Temp\ipykernel_16604\3310176048.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   full_df["LapTime"].fillna(full_df["Sector1Time"] + full_df["Sector2Time"] + full_df["Sector3Time"], inplace=True)

# %% [markdown]
# ### Stint Column

# %%
# 2025 Round 6 seems to have missing data in tyrelife, stint and tyre compound up until lap 23 so will drop this data 
full_df = full_df[~((full_df["RoundYear"] == "2025_6") & (full_df["LapNumber"] <= 24))]

# %% [markdown]
# ### Compound Column

# %%
# Compound has 57 rows that are null since its such a small amount compared to the data will drop these
full_df = full_df[~full_df["Compound"].isnull()]

# %% [markdown]
# ### Tyre Life Column

# %%
# Same will be applied to the tyrelife column
full_df = full_df[~full_df["TyreLife"].isnull()]

# %% [markdown]
# ## Outlier Evaluations

# %%
full_df["LapNumber"] = full_df["LapNumber"].astype("int64")
full_df["Stint"] = full_df["Stint"].astype("int64")
full_df["Compound"] = full_df["Compound"].astype("string")
full_df["TyreLife"] = full_df["TyreLife"].astype("int64")
full_df["Team"] = full_df["Team"].astype("string")
full_df["LapStartTime"] = pd.to_timedelta(full_df["LapStartTime"])
full_df["Position"] = full_df["Position"].astype("int64")
full_df["DriverID"] = full_df["DriverID"].astype("string")
full_df["LapType"] = full_df["LapType"].astype("string")
full_df["RoundYear"] = full_df["RoundYear"].astype("string")

# %% [markdown]
# ### Inlaps and Outlaps

# %%
# These laps will be dropped as they will skew the data 
full_df = full_df[full_df["LapType"] == "Lap"]

# %% [markdown]
# ### Varying Track Conditions

# %%
# Only keeping laps where the track was clear as these will skew lap times 
full_df = full_df[full_df["TrackStatus"] == 'Track Clear']

# %% [markdown]
# ### Weather Data

# %%
# Creating a dry and wet dataframe where if there was rainfall or if the drivers were on a wet or dry tyre compound will be associated with the adequate dataframe
dry_tyres = ['SOFT', 'HARD', 'MEDIUM']

wet_tyres = ['INTERMEDIATE', 'WET']

dry_full_df = full_df[(full_df["Rainfall"] == False) & (full_df["Compound"].isin(dry_tyres))]

wet_full_df = full_df[(full_df["Rainfall"] == True) | (full_df["Compound"].isin(wet_tyres))]

# %% [markdown]
# ### Dry Laptime Outlier Evaluations

# %%
for r in dry_full_df["RoundYear"].unique():
   plt.boxplot(dry_full_df.loc[dry_full_df["RoundYear"] == r, "LapTime"])
   plt.title(f"Round Number: {r}")
   plt.show()

# In 2024 Round 4 shows clear outliers
# In 2025 Rounds 6, 9, 17 and 18 show clear outliers will investigate these further

# %%
# Dropping clear outliers as shown in boxplots
drop_2024_4_rows = dry_full_df[(dry_full_df["RoundYear"] == "2024_4") & (dry_full_df["LapTime"] > 110)].index

dry_full_df.drop(drop_2024_4_rows, inplace=True)

drop_2025_6_rows = dry_full_df[(dry_full_df["RoundYear"] == "2025_6") & (dry_full_df["LapTime"] > 100)].index

dry_full_df.drop(drop_2025_6_rows, inplace=True)

drop_2025_9_rows = dry_full_df[(dry_full_df["RoundYear"] == "2025_9") & (dry_full_df["LapTime"] > 90)].index

dry_full_df.drop(drop_2025_9_rows, inplace=True)

drop_2025_18_rows = dry_full_df[(dry_full_df["RoundYear"] == "2025_18") & (dry_full_df["LapTime"] > 110)].index

dry_full_df.drop(drop_2025_18_rows, inplace=True)
# Out:
# C:\Users\Cillian\AppData\Local\Temp\ipykernel_16604\3820274468.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dry_full_df.drop(drop_2024_4_rows, inplace=True)
# C:\Users\Cillian\AppData\Local\Temp\ipykernel_16604\3820274468.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dry_full_df.drop(drop_2025_6_rows, inplace=True)
# C:\Users\Cillian\AppData\Local\Temp\ipykernel_16604\3820274468.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dry_full_df.drop(drop_2025_9_rows, inplace=True)
# C:\Users\Cillian\AppData\Local\Temp\ipykernel_16604\3820274468.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dry_full_df.drop(drop_2025_18_rows, inplace=True)

# %% [markdown]
# ### Wet Laptimes Outlier Evaluation

# %%
for r in wet_full_df["RoundYear"].unique():
   plt.boxplot(wet_full_df.loc[wet_full_df["RoundYear"] == r, "LapTime"])
   plt.title(f"Round Number: {r}")
   plt.show()

# Some outliers particularly in Round 9 and 21 but due to the wet weather or tyre compound this is natural so will leave this data

# %% [markdown]
# ### Dry Weather Data Outlier Evaluation

# %%
# No Outliers
plt.boxplot(dry_full_df["AirTemp"])
plt.title("AirTemp Box Plot")
plt.show()

# %%
# No Outliers
plt.boxplot(dry_full_df["Humidity"])
plt.title("Humidity Box Plot")
plt.show()

# %%
plt.boxplot(dry_full_df["Pressure"])
plt.title("Pressure Box Plot")
plt.show()
# No Clear outliers as 800 has around 2000 rows

# %%
plt.boxplot(dry_full_df["TrackTemp"])
plt.title("TrackTemp Box Plot")
plt.show()
# No Outliers

# %%
plt.boxplot(dry_full_df["WindDirection"])
plt.title("WindDirection Box Plot")
plt.show()
# No Outliers

# %%
plt.boxplot(dry_full_df["WindSpeed"])
plt.title("WindSpeed Box Plot")
plt.show()
# No Outliers

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Encoding Categorical Variables for Dry Dataframe
# - Compound
# - Fresh Tyre
# - Team
# - DriverID

# %%
# Getting Unique Values
dry_full_df["Compound"].unique()

# Creating a Map for different compounds
replace_compounds = {
    'SOFT': 1,
    'MEDIUM':2,
    'HARD':3
}

# Mapping the Compounds to their respective values
dry_full_df["Compound"] = dry_full_df["Compound"].map(replace_compounds)

# Repeating Process for Fresh Tyre
dry_full_df["FreshTyre"].unique()

replace_ft = {
    True : 1,
    False : 0
}

dry_full_df["FreshTyre"] = dry_full_df["FreshTyre"].map(replace_ft)

# Repeating Process for Team
dry_full_df["Team"].unique()

replace_team = {
    'Red Bull Racing': 1,
    'Ferrari': 2,
    'Mercedes': 3,
    'Aston Martin':4,
    'McLaren':5,
    'Williams':6,
    'Haas F1 Team':7,
    'Kick Sauber':8,          
    'Alpine':9,    
    'Racing Bulls':10
}

dry_full_df["Team"] = dry_full_df["Team"].map(replace_team)

# Repeating Same Process for DriverID
dry_full_df["DriverID"].unique().tolist()

replace_driver ={
    'max_verstappen':1,
    'leclerc':2,
    'russell':3,
    'perez':4,
    'sainz':5,
    'alonso':6,
    'norris':7,
    'piastri':8,
    'hamilton':9,
    'tsunoda':10,
    'albon':11,
    'kevin_magnussen':12,
    'zhou':13,
    'sargeant':14,
    'ricciardo':15,
    'ocon':16,
    'gasly':17,
    'bottas':18,
    'stroll':19,
    'hulkenberg':20,
    'bearman':21,
    'colapinto':22,
    'lawson':23,
    'doohan':24,
    'antonelli':25,
    'bortoleto':26,
    'hadjar':27
}

dry_full_df["DriverID"] = dry_full_df["DriverID"].map(replace_driver)
# Out:
# C:\Users\Cillian\AppData\Local\Temp\ipykernel_16604\714551401.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dry_full_df["Compound"] = dry_full_df["Compound"].map(replace_compounds)
# C:\Users\Cillian\AppData\Local\Temp\ipykernel_16604\714551401.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dry_full_df["FreshTyre"] = dry_full_df["FreshTyre"].map(replace_ft)
# C:\Users\Cillian\AppData\Local\Temp\ipykernel_16604\714551401.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dry_full_df["Team"] = dry_full_df["Team"].map(replace_team)
# C:\Users\Cillian\AppData\Local\Temp\ipykernel_16604\714551401.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dry_full_df["DriverID"] = dry_full_df["DriverID"].map(replace_driver)

# %% [markdown]
# ### Encoding Categorical Variables for Wet Dataframe
# - Compound
# - Fresh Tyre
# - Team
# - DriverID

# %%
# Repeating Same process as for dry but on wet df
wet_full_df["Compound"].unique().tolist()

replace_compounds = {
    'SOFT': 1,
    'MEDIUM':2,
    'HARD':3,
    'INTERMEDIATE':4,
    'WET':5
}

wet_full_df["Compound"] = wet_full_df["Compound"].map(replace_compounds)

wet_full_df["FreshTyre"].unique()

replace_ft = {
    True : 1,
    False : 0
}

wet_full_df["FreshTyre"] = wet_full_df["FreshTyre"].map(replace_ft)


wet_full_df["Team"].unique()

replace_team = {
    'Red Bull Racing': 1,
    'Ferrari': 2,
    'Mercedes': 3,
    'Aston Martin':4,
    'McLaren':5,
    'Williams':6,
    'Haas F1 Team':7,
    'Kick Sauber':8,          
    'Alpine':9,    
    'Racing Bulls':10
}

wet_full_df["Team"] = wet_full_df["Team"].map(replace_team)

wet_full_df["DriverID"].unique().tolist()

replace_driver ={
    'max_verstappen':1,
    'leclerc':2,
    'russell':3,
    'perez':4,
    'sainz':5,
    'alonso':6,
    'norris':7,
    'piastri':8,
    'hamilton':9,
    'tsunoda':10,
    'albon':11,
    'kevin_magnussen':12,
    'zhou':13,
    'sargeant':14,
    'ricciardo':15,
    'ocon':16,
    'gasly':17,
    'bottas':18,
    'stroll':19,
    'hulkenberg':20,
    'bearman':21,
    'colapinto':22,
    'lawson':23,
    'doohan':24,
    'antonelli':25,
    'bortoleto':26,
    'hadjar':27
}

wet_full_df["DriverID"] = wet_full_df["DriverID"].map(replace_driver)
# Out:
# C:\Users\Cillian\AppData\Local\Temp\ipykernel_16604\2328108365.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wet_full_df["Compound"] = wet_full_df["Compound"].map(replace_compounds)
# C:\Users\Cillian\AppData\Local\Temp\ipykernel_16604\2328108365.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wet_full_df["FreshTyre"] = wet_full_df["FreshTyre"].map(replace_ft)
# C:\Users\Cillian\AppData\Local\Temp\ipykernel_16604\2328108365.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wet_full_df["Team"] = wet_full_df["Team"].map(replace_team)
# C:\Users\Cillian\AppData\Local\Temp\ipykernel_16604\2328108365.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wet_full_df["DriverID"] = wet_full_df["DriverID"].map(replace_driver)

# %% [markdown]
# ### Dropping Redundant Columns

# %%
cols_to_drop = ['LapStartTime', 'TrackStatus','Deleted','LapType']

dry_full_df.drop(columns=cols_to_drop, inplace=True)

wet_full_df.drop(columns=cols_to_drop, inplace=True)
# Out:
# C:\Users\Cillian\AppData\Local\Temp\ipykernel_16604\4219603768.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dry_full_df.drop(columns=cols_to_drop, inplace=True)
# C:\Users\Cillian\AppData\Local\Temp\ipykernel_16604\4219603768.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wet_full_df.drop(columns=cols_to_drop, inplace=True)

# %% [markdown]
# ## Evaluating Multicolinearity

# %%
wet_full_df.isnull().sum()
# Out:
# LapTime            0
# LapNumber          0
# Stint              0
# Sector1Time        0
# Sector2Time        0
# Sector3Time        0
# SpeedI1          361
# SpeedI2            0
# SpeedFL            0
# SpeedST           69
# Compound           0
# TyreLife           0
# FreshTyre          0
# Team               0
# Position           0
# DriverID           0
# AirTemp            0
# Humidity           0
# Pressure           0
# Rainfall           0
# TrackTemp          0
# WindDirection      0
# WindSpeed          0
# RoundYear          0
# MedianLapTime      0
# Rank               0
# dtype: int64

# %%
correlations = dry_full_df.corr(method="pearson")

correlations["LapTime"]
# Out:
# LapTime          1.000000
# LapNumber       -0.232560
# Stint           -0.100334
# Sector1Time      0.700144
# Sector2Time      0.693214
# Sector3Time      0.424026
# SpeedI1         -0.153311
# SpeedI2         -0.188441
# SpeedFL         -0.183815
# SpeedST          0.231454
# Compound        -0.002797
# TyreLife        -0.099195
# FreshTyre        0.065366
# Team             0.025646
# Position         0.070397
# DriverID         0.032745
# AirTemp         -0.075992
# Humidity         0.146510
# Pressure         0.204345
# Rainfall              NaN
# TrackTemp       -0.363840
# WindDirection   -0.025845
# WindSpeed       -0.139492
# RoundYear       -0.062682
# MedianLapTime    0.989206
# Rank             0.064128
# Name: LapTime, dtype: float64
